# %%
from google.colab import drive
drive.mount('/content/drive')
# !wget/content/drive/MyDrive/Flowers Dataset.zip
# Out:
# Mounted at /content/drive
# /bin/bash: wget/content/drive/MyDrive/Flowers: No such file or directory

# %%
import numpy as np 
import pandas as pd 
from PIL import Image 
import matplotlib.pyplot as plt
import cv2

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass

# %%
Path = "/content/drive/MyDrive/Flowers Dataset.zip"

# %%
flowers = {}

# %%
for dirname, dirlist, filenames in os.walk(Path):
  flower_name = dirname.split('/')[-1]
  if dirname != Path :
        print("Number of {flower_name} images: {len(filenames)}")
        filePaths = []
        for filename in filenames:
            filePaths.append(os.path.join(Path, dirname, filename))
        flowers[flower_name] = filePaths

# %%
fig,ax = plt.subplots(1,3, figsize=(24, 12))

img1 = cv2.imread(Path)
img1 = cv2.cvtColor


img2 = cv2.imread(Path)
img2 = cv2.cvtColor


img3 = cv2.imread(Path)
img3 = cv2.cvtColor


plt.show()
